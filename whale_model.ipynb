# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -d  '/content/drive/My Drive/dataset_whale/train' '/content/drive/My Drive/dataset_whale/train.zip'
# Out:
# Archive:  /content/drive/My Drive/dataset_whale/train.zip
#   inflating: /content/drive/My Drive/dataset_whale/train/00022e1a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/000466c4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00087b01.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/001296d5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0014cfdf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0025e8c2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0026a8ab.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0031c258.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0035632e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0037e7d3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00389cd7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0042dcc4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0042ea34.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00467ae9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/004a97f3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/004c5fb9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/005c57e7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/006d0aaf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0078af23.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/007c3603.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00863b8c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/008809b5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/008baccf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0091c92b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/009dca38.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00a29f63.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00aa021c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00ab018e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00ac0e86.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00acb5a9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00ad9219.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00af84d8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00b2c0cd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00b588d6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00b7de10.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00be7f73.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00be9148.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00cf7bd3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00d3d48c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00d6b82e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00ded600.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00eab0e6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00ec0dcd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00f22419.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/00f4c92c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0101d22b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/010ecbb5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/010f1fe2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/011904f8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01228da4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/012621f1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01274a1e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01321d88.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01496f0b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0162c72f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01679a6d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01692e13.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0171d221.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0175c4c1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/017ec31f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/018722ca.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/018f26da.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01981e98.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/019cd867.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01aaa81a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01b83639.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01bd341c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01be6c48.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01c11eaf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01c28f3b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01cf1430.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01cf2e2e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01d117c5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01d4467a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01d890d8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01daeb5a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01dd608b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01e25788.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01e37453.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01e490cf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01ec6749.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01ed89f6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/01f17a15.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/020028b2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02012946.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02073b87.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0217abfb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/021dc6ac.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02239d12.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0237ca7a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/024144e5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0243ca95.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02453c9f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/024c6d37.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0252337b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02529c95.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02558f3a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/025c0ecb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/025fd2ea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02608d7a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0260c382.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0267139c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02715625.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/028d2ff2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02916b71.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02a12b73.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02a66def.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02a783c8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02aceb16.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02af1aa3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02c8235c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02c82510.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02cf6a52.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02cff75e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02d235f7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02e6188b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02ea0810.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/02ed3e6d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03034d4c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0316f962.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0317dee0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/031c75ef.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0320e985.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0323fcfc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03282162.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0331d7a8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03322101.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0344cc34.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03500d61.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0354d93d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0356c5ed.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/035ab2b4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0360c040.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0365b421.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/036b9b64.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/036bad0a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0375c878.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0376d91d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/037e59bc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0387bc35.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03910800.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03933dbb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0397dbdb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/039b1c58.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03a3593c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03b4ea17.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03b5f4e4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03c696a6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03c6a5c0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03cb4f5d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03d0f974.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03de1a54.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03e8e963.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03f158af.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03f8476f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03f8cf5a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03fb2408.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03fbb4cb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/03fe05bc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0400ccee.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/040860f2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/040898fc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/040c1cd4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/040d8913.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/040e5bd6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04182994.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/041e7370.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0422010d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/042fa04b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0435e09a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/043a5625.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0444f67e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0453720f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04559a53.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0466ed01.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0471a6a7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/047b1d89.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/048578f5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0485c4c1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04867dab.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0489f7e2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/048b9040.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04928fa7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0496e682.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04a39247.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04a91387.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04aaf2f9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04ad14b2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04b16181.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04b3714e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04b88a95.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04c06689.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04c5ec77.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04c73b64.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04cdb743.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04ce734a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04cee0bd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04d1f994.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04d2b8a3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04d69405.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04d7f905.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04dd6cc6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04e5cc2b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04eff153.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04fa6285.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/04fcc7f0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0504d072.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0504e8f8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05071be3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0512b13b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/051e6fbe.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0523d3a2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0524950b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0525ae51.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0528bc43.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05293254.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/052f5378.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05330b65.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0534772d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/053555fe.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0545526f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/054c4923.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05500217.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05510761.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05562539.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/055b8460.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05651187.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0566b8e8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/056b05e2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/057644d1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/057ce740.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/057d24dd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/058147c9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05859f6e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05898b05.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0592e297.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0594a048.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0595cef3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05a1c013.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05a273d8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05cc223e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05d10f3f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05d402e7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05d87e8f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05e50d1a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05eb989c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05ebc21b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05edf5e5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05ee4ba3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05ef7149.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05f4fd87.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05f7a40d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/05fffe26.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0603a403.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/060999c4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06127f81.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06176b42.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0617f982.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06194c8f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06252a55.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06256148.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0629271e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06395c21.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0639d07c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/063acadc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/063e62a9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/064d2674.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06562b7d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06590146.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/065de1f0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06654cf5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/066860e3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06709a5b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/068a256b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/068ddcd9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/069d05ca.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/069e0d01.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06a2edf4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06ab0bdc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06b3fe4d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06b55250.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06b62519.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06bd0e02.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06bdc5d1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06bfa037.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06c0c5b6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06c5c28e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06cbdaa5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06cf4233.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06d7be52.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06e3e8b5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06e43d7a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06e5ca1c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06e622e0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06e8a669.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06ed0f2e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06f3adae.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06f3cbf8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/06ffe77b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0701d937.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0705d206.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/070e6c95.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0727715c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0739fcdc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0745ef3f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07480326.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0749d9c2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/074ceb3f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/074f068b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0753654f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/075a3b48.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/076f28ee.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0774e535.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07860ce9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0797d002.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07992508.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/079e4dad.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07a2d97d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07a49e8f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07a58418.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07a5d734.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07a7b921.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07aa9e43.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07b68012.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07b74c39.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07b7d9ca.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07b8a5e7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07b8b278.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07be1da5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07c0c8c2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07c2def7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07c4cbbd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07c94f4a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07ca5dfa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07e96de0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07ecc5ba.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07eee8cb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07f13540.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/07f4cb9a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08082d1f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/080897a7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/080fd2a9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/081a21e1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/081e9ebb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/081ec076.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0820bf9e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08245860.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08254c44.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/082d754a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08341514.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0841855c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08476cf8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/084a3e34.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08527158.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08593f8e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/085e1213.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0868ded1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/086b3f1f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/086cc275.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0870fa6b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/087495e6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/088cc3cc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/089ab9b8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/089f0ba9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08a1088e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08a3857b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08a8809b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b158fd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b4be31.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b4e3a7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b62734.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b64b7c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08b9dae5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08c242be.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08d15c2a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08d31d59.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08d3778f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08ea7e5e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08f30112.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/08fc2ceb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0900fbae.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0913e33a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09166955.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/091dc8dc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09239cbc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/092ddfd3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09394b01.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/093d43ac.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0942db2a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/094a67d1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/095e2b1a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09657e55.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/096a26de.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/096aa6d9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/096f4caa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09783e8c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/097f138b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09824683.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09827e32.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/098da275.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/099035b0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0993be71.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/099d6571.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09a3fd95.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09a40708.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09b39d03.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09b893e6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09cf3d9b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09e5ed31.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09f70419.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/09f88db2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a00c8c5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a0b2a01.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a0bc259.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a14e622.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a22ee49.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a254aa7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a29c0d2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a341eef.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a342e77.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a3b0493.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a3b5971.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a3dbc55.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a4e0385.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a552569.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a5c0f48.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a60ed9d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a68446c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a698a67.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a6be385.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a70aa2d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a81a170.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a904007.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a96b20e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0a96d8c0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0aa416d8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0aa7b03e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ab00a28.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0acce63b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ada5fa1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ae14ed7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ae69f1e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ae90da3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0aed1250.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0aef7efd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0afa74a8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b0138cb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b02fbcd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b101019.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b142906.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b17a3bc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b1d25f5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b1e39ff.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b23f8c1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b255c73.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b31b634.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b32e254.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b352859.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b43e675.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b4694ad.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b4e02f3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b635230.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b673ec4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b6f6990.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b708127.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b7b7f00.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0b7dbf66.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ba015bb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ba20dd3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ba82fe7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ba97567.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bab8224.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bad785d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0baeeb07.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0baf0dcb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bc1562c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bc17b0e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bc48856.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bc914f7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bcd5dea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bd0a563.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bd8ff0b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bde3564.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0be30752.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0beb8899.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0bfb2b72.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c09bf79.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c0f34f2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c1155bb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c11fa0c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c222bc2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c290363.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c35fcb4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c38a6b4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c4f7a83.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c575867.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c589ccc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c5de573.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c6170eb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c61dbc6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c64ae81.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c6542fe.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c6aea15.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c6c9b3c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c6eb67b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c7e35b0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c814951.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c85c12f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c86b603.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c88a7aa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c8983f3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c8baedc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0c8def46.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ca67fe7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ca843f9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0caa3541.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cac8109.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cc88b7c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cca82c9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ccdded0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ccf9364.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cd6cc7b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cdc3e24.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ceba3ce.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cef66af.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cf59b47.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0cf7c91e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d01adda.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d06e4da.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d0840cf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d10afed.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d10de68.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d17373d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d20a02f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d2110ff.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d21dc39.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d26960d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d32dfc5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d45d434.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d4804fe.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d482f6b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d4e8a7e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d614401.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d62e654.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d6978c3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d6c23c0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d6e8874.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d726185.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d8a9dda.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0d8cb5d6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dab2960.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dacddec.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0db4410f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dbbc244.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dc4a773.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dd07e82.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dd0edf4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dd507d3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dd5c3ed.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0df64f08.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0df85a56.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0df89aea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0df9e124.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0dfa5cd6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e073d29.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e137419.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e13c663.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e241828.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e2477a6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e24fbcc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e267188.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e2bee83.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e317827.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e400a28.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e46bc37.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e4e6449.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e5996a4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e5b550e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e5ce2da.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e672fdd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e6ac93b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e6c8888.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e74c12b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e861f4b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e87967f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e891ec9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e8c8c34.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e8ce258.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e923527.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e9ccb74.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0e9ed45b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ea56c4c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0eb0a241.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ebcc0a9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ec24624.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ec2e3e8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ec4d882.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0edaba42.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ee2d16d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ef0f16e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0eff71ec.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f0d3839.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f257eb1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f399c2a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f51444d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f528eb1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f550bb8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f572518.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f611096.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f6f6880.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f776f50.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f8136f0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f83217e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f86a67d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0f93f54c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fa288cf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fa2da8f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fb2525d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fb4c4dd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fb6482b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fb7d824.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fbba784.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fbc91d1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fc49194.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fc584fc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fc63e94.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fcbbfeb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fd95216.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fddb687.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fe8cd19.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0fe96da7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ffa7cf0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/0ffbb51e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10022bd2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/101fb476.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10257233.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10350c3e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/103529b2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/103b8cfa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/103c3a62.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/103f7855.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/104713f3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/104ef864.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1050edfc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10554174.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/106d0a10.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1070540a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1073359b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1076222e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/107a4c8c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10807a6e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/108a71d9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/108b023e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1096053c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/1096db60.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10971b3f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/109917ef.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/109d1dc5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10a4fc3c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10a8fc59.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10aa1828.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10ae4f14.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10bc0024.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10bd94ea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/10c032f0.jpg
# ...
#   inflating: /content/drive/My Drive/dataset_whale/train/fa2f0ab8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa3560bc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa393b35.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa42a499.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa4822c4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa4c20f2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa5ed9f9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa617666.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa62a2e8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa642aad.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa6f6102.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa716a1a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa7a3a2d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa7f1dab.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa8aa8ea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa8ed4af.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fa9c24f0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faa48f04.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faaa51e1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faaac65a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faab2561.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faab9f4d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faac65ad.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fabb59a6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fabfd54e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fac272d9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fac671ec.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/facbd651.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fad13793.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fad1485a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fae776ef.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fae8e8dd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faec3aea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/faed814e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb0f9051.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb16503f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb194792.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb1baada.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb1ff65c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb216144.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb2271f1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb2ccd75.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb3f7ab4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb45b2fa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb479aa0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb530edf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb55240e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb578eda.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb5f5b93.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb70ae36.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb757062.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb7b0e02.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb83238e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb881c99.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb93a9ab.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb952a85.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fb97ec20.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fba04b43.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fba1e2ee.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbb679be.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbbeb867.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbc32391.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbd1322d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbdab2a0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbe0cb16.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbe419df.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbf1c9d5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fbfe14ff.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc09fb19.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc0c2037.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc120e58.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc13f954.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc14e6c2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc1882b1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc1a3ba0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc226174.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc239c81.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc29d7ce.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc3a76f2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc408b0a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc44480a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc5000ba.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc51873a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc547b47.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc54d7de.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc5a9810.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc6177e8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc6f3123.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc72a703.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc7a3fd6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc7bbbe2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc8552cf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc8e2b9f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc987c42.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fc989bd1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fca04935.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcaa754f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcb09150.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcbf11ef.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcc22826.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcc84c8e.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcc8d828.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcde10a2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fce89b48.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcea175a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcefa4a5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcf03ecc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fcf9499f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd0c8231.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd137762.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd176ee0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd179440.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd30f7e6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd35e96d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd35f470.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd3a6143.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd415a52.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd421daf.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd46dc70.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd4d499a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd4fce43.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd50aaf3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd547a11.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd58777d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd640630.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd696375.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd77aed8.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd7aedbe.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd8517b4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd8d4668.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd92a4b9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd9587a6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd9c0764.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fd9fac4d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fda9f2dd.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdaeed3f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdb4a622.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdc286d7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdc37bf3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdc86e6b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdca36b9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdcc3b84.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdd5b843.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdf87a0d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fdfcbbda.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe004da5.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe119576.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe14c07d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe16bf7a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe1ad607.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe2e3631.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe3311a9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe3329b4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe450c91.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe4c0693.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe4ce0c3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe4fa036.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe529671.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe5f33d6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe6549c9.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe673380.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe67be62.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe7ee58c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe80a64d.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe8aa03b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe8cd7e1.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe9264a2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe937459.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fe993f2c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fea13a5a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fea38b0a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fea57d56.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fea7e505.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb15de4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb1ecd3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb32d26.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb784e0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb971ea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/feb9ded0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fec336f2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fec501c7.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fed3bc99.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fee9209b.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fefc845c.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fefe9bdc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff0d2705.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff0de88a.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff0df395.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff24f0ea.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff2760bb.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff2965ba.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff2c20cc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff2d0d82.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff3509c0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff38054f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff3c2c25.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff3f151f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff421460.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff4bb3a4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff5a5ed4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff6946b4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff6c1a92.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff6d6894.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff7247f6.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff8b2ad0.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff92447f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ff9d60a3.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffa6b9ac.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffa78ccc.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffb71ac2.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffbaa734.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffbca206.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffc0b437.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffc6986f.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffcfd124.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffd01d82.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffd1e7aa.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffe5c306.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffeaa7a4.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/ffecec63.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fff04277.jpg
#   inflating: /content/drive/My Drive/dataset_whale/train/fffd4260.jpg

# %%
import torch.nn as nn
import torch
import torch.optim as optim
import pickle
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import TensorDataset, DataLoader,Dataset
import matplotlib.pyplot as plt
import time
import os
import copy
import pandas as pd
import PIL.Image as Image
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
train_on_gpu = True
from sklearn.model_selection import train_test_split

# %%
model_name = "densenet"
num_classes = 3776
feature_extract = False

# %%
# path_train = "../input/train-val/train.csv"
# path_val = "../input/train-val/val.csv"

train = pd.read_csv("/content/drive/My Drive/dataset_whale/train.csv")
train.head()
df_train, df_val = train_test_split(train, test_size=0.2, random_state=63)

print(len(df_train))
print(len(df_val))

# df_train = pd.read_csv("../input/humpback-whale-identification/train.csv")
# #df_train = pd.read_csv("../input/train-val/train.csv")
# df_val = pd.read_csv("../input/train-val/val.csv")
# print(len(df_train))
# print(len(df_val))
# print(df_train.head())
# print(df_val.head())
# Out:
# 7880
# 1970

# %%
def prepare_labels(y):
    # From here: https://www.kaggle.com/pestipeti/keras-cnn-starter
    values = np.array(y)
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(values)

    onehot_encoder = OneHotEncoder(sparse=False)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_encoded = onehot_encoder.fit_transform(integer_encoded)

    y = onehot_encoded
    return y, label_encoder


y_train, le_train = prepare_labels(df_train['Id'])
#train:7880
#val:1970
y_train = y_train[range(7880)]
y_val = y_train[range(1970)]
#y_val, le_val = prepare_labels(df_val['Id'])
print((y_train).shape)
print(y_val.shape)
# Out:
# (7880, 3776)
# (1970, 3776)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
# For train and val, datafolder = "../input/humpback-whale-identification/train"
# For test, datafolder = "../input/humpback-whale-identification/test"

# For train, datatype = "train"
# For val, datatype = "val"
# For test, datatype = "test"

# For train, y = y_train
# For val, y = y_val

# For train, df = df_train
# For val, df = df_val

# Finished # IMPORTANT: Remember to split y into train and val before creating object of this class
class Whaledataset(Dataset):
    def __init__(self, datafolder, datatype, transform, y, df):
        self.datafolder = datafolder
        self.datatype = datatype
        self.transform = transform
        self.y = y # y is same for both train and val
        if datatype =="train":
            self.df = df.values
        if datatype =="val":
            self.df = df.values
        # self.df not there for test because no df for test        
        self.image_list = [s for s in os.listdir(datafolder)]
        
    def __len__(self):
        if self.datatype == "train":
            return 7880
        elif self.datatype == "val":
            return 1970
        elif self.datatype == "test":
            return len(os.listdir(self.datafolder))
        
        #return len(os.listdir(self.image_list)) #Returns same value for train and val. Correct later
    
    def __getitem__(self, idx):
        if self.datatype =='train' or self.datatype =="val":
            img_name = os.path.join(self.datafolder, self.df[idx][0])
            label = self.y[idx]
            
        elif self.datatype == 'test':
            img_name = os.path.join(self.datafolder, self.image_list[idx])
            label = np.zeros((1970,))

        image = Image.open(img_name).convert('RGB')
        image = self.transform(image)
        if self.datatype == 'train' or self.datatype == "val":
            return image, label
        elif self.datatype == 'test':
            # so that the images will be in a correct order
            return image, label, self.image_list[idx]

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False


def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):
    # Initialize these variables which will be set in this if statement. Each of these
    #   variables is model specific.
    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet34
        """
        model_ft = models.resnet34(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "alexnet":
        """ Alexnet
        """
        model_ft = models.alexnet(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "vgg":
        """ VGG11_bn
        """
        model_ft = models.vgg11_bn(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier[6].in_features
        model_ft.classifier[6] = nn.Linear(num_ftrs,num_classes)
        input_size = 224

    elif model_name == "squeezenet":
        """ Squeezenet
        """
        model_ft = models.squeezenet1_0(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        model_ft.classifier[1] = nn.Conv2d(512, num_classes, kernel_size=(1,1), stride=(1,1))
        model_ft.num_classes = num_classes
        input_size = 224

    elif model_name == "densenet":
        """ Densenet
        """
        model_ft = models.densenet121(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        num_ftrs = model_ft.classifier.in_features
        model_ft.classifier = nn.Linear(num_ftrs, num_classes)
        input_size = 224

    elif model_name == "inception":
        """ Inception v3
        Be careful, expects (299,299) sized images and has auxiliary output
        """
        model_ft = models.inception_v3(pretrained=use_pretrained)
        set_parameter_requires_grad(model_ft, feature_extract)
        # Handle the auxilary net
        num_ftrs = model_ft.AuxLogits.fc.in_features
        model_ft.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)
        # Handle the primary net
        num_ftrs = model_ft.fc.in_features
        model_ft.fc = nn.Linear(num_ftrs,num_classes)
        input_size = 299

    else:
        print("Invalid model name, exiting...")
        exit()

    return model_ft, input_size

# Initialize the model for this run
model_ft, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=True)

# Print the model we just instantiated
print(model_ft)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=3776, bias=True)
# )

# %%
train_transforms = transforms.Compose([
                                      transforms.Resize((224,224)),
                                      transforms.RandomHorizontalFlip(0.5),
                                      transforms.RandomAffine(30),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                             std=[0.229, 0.224, 0.225])
    ])
val_transforms = transforms.Compose([
                                      transforms.Resize((224,224)),
                                      transforms.RandomHorizontalFlip(0.5),
                                      transforms.RandomAffine(30),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                             std=[0.229, 0.224, 0.225])
    ])

test_transforms = transforms.Compose([
                                       transforms.Resize((224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean = [0.485, 0.456, 0.406],
                                                              std = [0.229, 0.224, 0.225])
])

# %%
# Write function def accuracy here

def accuracy(outputs,labels):
    preds = outputs
    #print(type(preds), type(outputs))
    #preds_idx = np.argmax(preds, axis =1)
    #labels_idx = np.argmax(labels, axis =1)
    preds_idx = torch.argmax(preds, dim=1)
    ##print(preds_idx)
    labels_idx = torch.argmax(labels, dim=1)
    ##print(labels_idx)
    #preds_values, preds_idx = torch.max(preds, 1)
    #outputs_values, outputs_idx = torch.max(outputs, 1)
    #print(preds.shape)
    #print(labels.shape)
    return (preds_idx==labels_idx).float().sum()

train_datafolder = "/content/drive/My Drive/dataset_whale/train"
train_datatype = "train"
train_df = df_train
train_transform = train_transforms
train_y = y_train
batch_size = 32
num_workers = 0

val_datafolder = "/content/drive/My Drive/dataset_whale/train"
val_datatype = "val"
val_df = df_val
val_transform = val_transforms
val_y = y_val
batch_size = 32
num_workers = 0


def train(batch_size = 32, epochs = 10, transform = None):
    tfmd_dataset = Whaledataset(datafolder = train_datafolder, datatype = train_datatype, df = train_df , 
                                transform = train_transform, y = train_y)
    dataloader = torch.utils.data.DataLoader(tfmd_dataset, batch_size = batch_size, shuffle=True, 
                                             num_workers=num_workers)
    
    val_dataset = Whaledataset(datafolder = val_datafolder, datatype = val_datatype, df = val_df , 
                                transform = val_transform, y = val_y)
    
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size = batch_size, shuffle=True, 
                                             num_workers=num_workers)
    
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model_ft.parameters(), lr=0.0001)
    
    if torch.cuda.is_available():
        model_ft.cuda()
        nn.DataParallel(model_ft)
        print("GPU")
    epoch_loss_data = []
    epoch_accuracy_data = []

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    print(device)
    
    for epoch in range(1,epochs+1):  # loop over the dataset multiple times
        i = 0.0
        running_loss, running_loss_total, epoch_accuracy = 0.0, 0.0, 0.0
        val_running_loss, val_running_loss_total, val_epoch_accuracy = 0.0, 0.0, 0.0
        for i, data in enumerate(dataloader, 0):
            # get the inputs
            inputs, labels = data
            labels = labels.double()
            inputs, labels = inputs.to(device), labels.to(device)
        
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward + backward + optimize
            outputs = model_ft(inputs).double()
            #print(outputs.size())
            #print(labels.size())
            
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()

            # print statistics
            epoch_accuracy += accuracy(outputs,labels)
            #print(epoch_accuracy)
            #running_epoch_acc = float(epoch_accuracy)/float((labels.size()[0] * (i+1)))
            running_loss += loss.item()
            #running_loss_total += loss.item()
            '''if i%30 == 29:
                print('[%d, %5d] loss: %.3f, epoch_accuracy: %f' % (epoch, i + 1, running_loss, running_epoch_acc))
                running_loss = 0.0'''
            
            '''if i%100 == 99:
                torch.save(model_ft.state_dict(), 'checkpoint')
                torch.save(optimizer.state_dict(), 'optimizer_checkpoint')
                with open('Running_loss.p','wb') as f:
                    pickle.dump(running_loss_total,f)
                with open('Running_accuracy.p','wb') as f:
                    pickle.dump(running_epoch_acc,f)
        epoch_accuracy_data.append(running_epoch_acc)
        epoch_loss_data.append(running_loss_total)'''
            
        epoch_accuracy = float(epoch_accuracy)/float(32 * (i+1))
        print('[%d, %5d] loss: %.3f, epoch_accuracy: %f' % (epoch, i + 1, running_loss, epoch_accuracy))
        running_loss = 0.0
        epoch_accuracy = 0.0
        
        for i, data in enumerate(val_dataloader,0):
            inputs, labels = data
            labels = labels.double()
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_ft(inputs).double()
            loss = criterion(outputs, labels)
            val_epoch_accuracy += accuracy(outputs,labels)
            val_running_epoch_acc = float(val_epoch_accuracy)/float((labels.size()[0] * (i+1)))
            val_running_loss += loss.item()
            '''if i%30 == 29:
                print('[%d, %5d] val loss: %.3f, val_epoch_accuracy: %f' % (epoch, i + 1, val_running_loss, val_running_epoch_acc))
                val_running_loss = 0.0
            '''
        val_epoch_accuracy = float(val_epoch_accuracy)/float(32 * (i+1))    
        print('[%d, %5d] val loss: %.3f, val_epoch_accuracy: %f' % (epoch, i + 1, val_running_loss, val_epoch_accuracy))
        val_running_loss = 0.0
        val_epoch_accuracy = 0.0

# %%
train(transform=train_transforms,epochs=25,batch_size=32)
# Out:
# GPU
# cuda:0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-6ff54e1a2fbe> in <module>()
# ----> 1 train(transform=train_transforms,epochs=25,batch_size=32)
#
# <ipython-input-20-a0cbeb813081> in train(batch_size, epochs, transform)
#      75             #print(labels.size())
#      76
# ---> 77             loss = criterion(outputs, labels)
#      78
#      79             loss.backward()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     599                                                   self.weight,
#     600                                                   pos_weight=self.pos_weight,
# --> 601                                                   reduction=self.reduction)
#     602
#     603
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    2112         raise ValueError("Target size ({}) must be the same as input size ({})".format(target.size(), input.size()))
#    2113
# -> 2114     return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#    2115
#    2116
#
# KeyboardInterrupt:

# %%
test_datafolder = "../input/humpback-whale-identification/test"
test_datatype = "test"
test_transform = test_transforms
batch_size = 32
num_workers = 0
sub = pd.read_csv("../input/humpback-whale-identification/sample_submission.csv")
def test(batch_size, transform, model):
    test_set = Whaledataset(datafolder = test_datafolder, datatype = test_datatype, transform = test_transform, y = y_train, df = df_train)
    test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, num_workers=num_workers)
    model.cuda()
    model.eval()
    for (data, target, name) in test_loader:
        data = data.cuda()
        output = model(data)
        print(output)
        output = output.cpu().detach().numpy()
        for i, (e, n) in enumerate(list(zip(output, name))):
            sub.loc[sub['Image'] == n, 'Id'] = ' '.join(le_train.inverse_transform(e.argsort()[-5:][::-1]))
    sub.to_csv('basic_model.csv', index=False)

# %%
test(batch_size, test_transform, model_ft)
